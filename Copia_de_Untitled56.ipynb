# %% [markdown]
# <a href="https://colab.research.google.com/github/bmendoz/ejemplo/blob/main/Copia_de_Untitled56.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
H1 = pd.read_csv("H1.csv")

# %%
H1[H1.IsCanceled==1].head()
# Out:
#     IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 8            1        85             2015             July
# 9            1        75             2015             July
# 10           1        23             2015             July
# 27           1        60             2015             July
# 32           1        96             2015             July
#
#     ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 8                      27                      1                     0
# 9                      27                      1                     0
# 10                     27                      1                     0
# 27                     27                      1                     2
# 32                     27                      1                     2
#
#     StaysInWeekNights  Adults  Children  ...      DepositType        Agent  \
# 8                   3       2         0  ...  No Deposit               240
# ...

# %%
df1 = H1['ArrivalDateYear'].map(str) + H1['ArrivalDateWeekNumber'].map(str)

# %%
df2 = H1.IsCanceled

# %%
df3= pd.concat([df1, df2], axis = 1)

# %%
df3 = df3[df3.IsCanceled ==1]

# %%
df3.rename(columns={0: 'Fulldate', 'IsCanceled': 'IsCanceled'}, inplace=True)

# %%
df3 = df3.groupby('Fulldate').agg(sum)

# %%
df3.head()
# Out:
#           IsCanceled
# Fulldate
# 201527            41
# 201528            48
# 201529            87
# 201530            74
# 201531           101
